# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'originated', 'anarchism', 'of', 'as', 'term', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                        stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
            inputs=embed, labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time

num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.645092
# Nearest to also: ise, dandy, indicated, mea, perceive, connectives, boomed, apolitical,
# Nearest to an: alkyne, gpled, microwaves, floor, abridged, cheats, channelled, incompatible,
# Nearest to by: thalamus, bridgeport, aasen, haart, majorca, explanation, merge, hauer,
# Nearest to UNK: supports, gutman, fd, castle, garrison, italia, infield, spectator,
# Nearest to to: exceeding, minucius, modernised, barnard, gaspard, sill, omim, regulator,
# Nearest to one: gender, fungus, lanes, cotswolds, rumored, electromagnetism, consult, cosmogony,
# Nearest to three: redefined, cacm, addison, unsustainable, ethertype, stoics, homicides, cha,
# Nearest to which: bernstein, slack, declaration, wonderland, convoy, bank, defend, soil,
# Nearest to while: disabilities, reject, outperform, marvellous, pickups, nucleophilic, interstellar, dire,
# Nearest to often: huts, abrasive, gesenius, konstantin, pearls, sahrawi, handed, sharon,
# Nearest to for: bush, quicksilver, buoyant, biographer, cluster, discredit, roussimoff, flapping,
# Nearest to in: mactutor, darkness, disquieting, phys, ioannes, nieuwe, ky, jima,
# Nearest to there: enlarge, may, emancipation, flourishes, chronological, dependency, conde, armada,
# Nearest to or: significance, kazakhstan, spoleto, mislead, mined, intoxication, discoveries, flap,
# Nearest to united: avidly, were, nova, hurley, impiety, convenes, stresses, bligh,
# Nearest to so: ladder, olwen, steering, agreements, straddle, sleepers, lacked, labels,
# Average loss at step 2000: 4.361492
# Average loss at step 4000: 3.872229
# Average loss at step 6000: 3.784399
# Average loss at step 8000: 3.682124
# Average loss at step 10000: 3.621071
# Nearest to also: connectives, which, influenza, still, rutger, there, youngest, not,
# Nearest to an: the, brahmagupta, caroline, meuse, fucked, mouton, recreational, vaulted,
# Nearest to by: was, been, as, is, disconnected, with, in, has,
# Nearest to UNK: kerry, rebounding, preoccupations, by, albigensian, resurrected, classmate, felicity,
# Nearest to to: minucius, fleeing, achromatic, biographers, rap, moribund, forall, irritation,
# Nearest to one: three, two, six, four, seven, eight, five, cult,
# Nearest to three: five, six, seven, four, eight, two, nine, zero,
# Nearest to which: who, messiah, that, also, this, it, dunedin, archaeologists,
# Nearest to while: reject, fragmentation, untouchables, dire, dry, with, basse, murr,
# Nearest to often: accounting, sometimes, looming, huts, multicellular, lair, majorca, typified,
# Nearest to for: wizardry, with, buoyant, in, of, battlecruisers, watercolors, pedro,
# Nearest to in: on, of, from, shadowrun, with, at, for, into,
# Nearest to there: it, he, they, andamans, restraint, never, also, callisthenes,
# Nearest to or: and, carps, suharto, s, minucius, errand, urim, tetrapods,
# Nearest to united: past, avidly, stresses, nova, petrified, overridden, sap, pumpkin,
# Nearest to so: ladder, olwen, steering, straddle, scams, orientations, agreements, lsch,
# Average loss at step 12000: 3.604534
# Average loss at step 14000: 3.566873
# Average loss at step 16000: 3.411138
# Average loss at step 18000: 3.456280
# Average loss at step 20000: 3.537662
# Nearest to also: still, which, now, connectives, not, there, never, it,
# Nearest to an: mouton, the, seaweed, attrition, picchi, akbar, fertilizers, paws,
# Nearest to by: be, with, for, were, as, fins, sulawesi, through,
# Nearest to UNK: k, acura, bowl, anytime, e, reconstruct, autonomic, gaussian,
# Nearest to to: may, prokaryotes, can, might, will, maidstone, not, would,
# Nearest to one: two, four, three, seven, eight, five, six, nine,
# Nearest to three: four, five, seven, six, two, eight, zero, nine,
# Nearest to which: this, that, who, messiah, it, also, but, there,
# Nearest to while: but, and, with, untouchables, from, dire, basse, moreover,
# Nearest to often: sometimes, who, widely, accounting, today, looming, still, typified,
# Nearest to for: with, by, from, of, in, histology, barbarous, wizardry,
# Nearest to in: at, with, on, from, during, shadowrun, alibi, for,
# Nearest to there: it, they, he, which, now, still, also, disappeared,
# Nearest to or: and, than, suharto, with, slander, southerly, bathe, aquarii,
# Nearest to united: past, avidly, koichi, south, overridden, stresses, petrified, sap,
# Nearest to so: ladder, orientations, lsch, lacked, sleepers, olwen, labels, steering,
# Average loss at step 22000: 3.503969
# Average loss at step 24000: 3.492429
# Average loss at step 26000: 3.479530
# Average loss at step 28000: 3.484459
# Average loss at step 30000: 3.502608
# Nearest to also: still, now, often, which, sometimes, it, never, connectives,
# Nearest to an: picchi, mouton, attrition, howstuffworks, philippi, francesco, haughty, akbar,
# Nearest to by: were, under, been, from, locator, pancakes, was, when,
# Nearest to UNK: radioactivity, consort, nard, mattel, e, depreciation, sidereal, playing,
# Nearest to to: would, might, will, can, biographers, modernised, irritation, nyc,
# Nearest to one: two, four, seven, eight, six, three, five, nine,
# Nearest to three: four, five, seven, six, two, eight, nine, zero,
# Nearest to which: this, that, it, what, also, messiah, who, hugh,
# Nearest to while: but, is, though, interphase, dry, dire, when, murr,
# Nearest to often: sometimes, also, still, widely, commonly, there, usually, accounting,
# Nearest to for: with, eva, wizardry, when, buoyant, devastated, from, overturning,
# Nearest to in: during, at, of, under, from, on, since, between,
# Nearest to there: they, it, he, still, now, often, we, who,
# Nearest to or: and, suharto, than, bathe, lasi, tutte, petropavlovsk, rashi,
# Nearest to united: past, overridden, koichi, avidly, petrified, stresses, south, nova,
# Nearest to so: ladder, lacked, orientations, tanistry, sleepers, too, lsch, olwen,
# Average loss at step 32000: 3.500666
# Average loss at step 34000: 3.490028
# Average loss at step 36000: 3.455862
# Average loss at step 38000: 3.303400
# Average loss at step 40000: 3.431174
# Nearest to also: which, now, often, still, sometimes, usually, never, there,
# Nearest to an: haughty, seduction, abridged, ym, attrition, picchi, glee, incompatible,
# Nearest to by: with, pancakes, was, when, as, repatriation, berkelium, brokers,
# Nearest to UNK: b, seq, james, purists, banish, oliva, tantra, woodcut,
# Nearest to to: irritation, will, could, calvino, can, festive, must, might,
# Nearest to one: seven, six, two, eight, three, four, five, nine,
# Nearest to three: four, six, five, two, seven, eight, nine, one,
# Nearest to which: that, this, also, who, it, messiah, often, there,
# Nearest to while: but, though, when, however, although, interphase, where, is,
# Nearest to often: sometimes, usually, still, widely, also, commonly, generally, frequently,
# Nearest to for: if, of, with, raping, in, buoyant, botanicals, histology,
# Nearest to in: during, from, on, at, of, with, and, since,
# Nearest to there: they, it, he, still, now, often, amo, she,
# Nearest to or: and, than, a, kanji, carlisle, daniel, uncountably, congressional,
# Nearest to united: past, koichi, seventh, petrified, avidly, gallbladder, overridden, stresses,
# Nearest to so: ladder, orientations, sleepers, lacked, lsch, ramjet, sem, olwen,
# Average loss at step 42000: 3.437230
# Average loss at step 44000: 3.451869
# Average loss at step 46000: 3.448847
# Average loss at step 48000: 3.353027
# Average loss at step 50000: 3.380403
# Nearest to also: still, now, often, which, sometimes, never, usually, freak,
# Nearest to an: mouton, ym, guaranteed, incompatible, picchi, locked, another, attrition,
# Nearest to by: under, scottsdale, was, through, in, with, locator, among,
# Nearest to UNK: lascaris, joking, caracas, smokey, kokomo, burali, aire, extras,
# Nearest to to: may, can, might, could, must, would, ella, yup,
# Nearest to one: six, eight, seven, two, nine, four, three, five,
# Nearest to three: four, six, eight, seven, two, nine, five, zero,
# Nearest to which: that, this, also, who, often, usually, what, these,
# Nearest to while: but, when, however, though, although, where, after, for,
# Nearest to often: sometimes, usually, commonly, generally, widely, frequently, still, also,
# Nearest to for: while, smoked, havre, without, gunpoint, rpr, including, programs,
# Nearest to in: of, during, from, on, since, bahadur, within, monsters,
# Nearest to there: they, it, he, still, now, we, she, yoannis,
# Nearest to or: and, than, bathe, decomposed, minorca, quipped, while, thayer,
# Nearest to united: koichi, past, seventh, gallbladder, avidly, sap, stresses, overridden,
# Nearest to so: lacked, then, barrington, orientations, when, ladder, sleepers, she,
# Average loss at step 52000: 3.440975
# Average loss at step 54000: 3.423464
# Average loss at step 56000: 3.437783
# Average loss at step 58000: 3.395529
# Average loss at step 60000: 3.393229
# Nearest to also: now, still, often, sometimes, never, usually, which, generally,
# Nearest to an: mouton, ym, haughty, picchi, stamp, philippi, guaranteed, paws,
# Nearest to by: through, when, versace, under, with, fins, pancakes, cass,
# Nearest to UNK: caesars, aka, joking, sayings, radiate, reconciling, anytime, depp,
# Nearest to to: would, may, modernised, toppings, achromatic, winchell, omim, must,
# Nearest to one: seven, two, six, four, nine, eight, five, three,
# Nearest to three: five, four, six, eight, seven, two, nine, one,
# Nearest to which: that, this, what, it, who, also, however, these,
# Nearest to while: when, though, after, before, although, however, but, moreover,
# Nearest to often: sometimes, usually, commonly, generally, frequently, widely, still, also,
# Nearest to for: of, including, buoyant, wizardry, after, while, although, and,
# Nearest to in: within, during, alibi, at, of, on, backstreet, throughout,
# Nearest to there: they, it, now, still, he, this, we, she,
# Nearest to or: and, than, decomposed, thayer, remedies, bromine, bathe, berkelium,
# Nearest to united: past, koichi, gallbladder, seventh, overridden, itt, sap, stresses,
# Nearest to so: lacked, barrington, then, wargames, tanistry, orientations, freda, even,
# Average loss at step 62000: 3.239041
# Average loss at step 64000: 3.254866
# Average loss at step 66000: 3.399360
# Average loss at step 68000: 3.394770
# Average loss at step 70000: 3.358188
# Nearest to also: now, still, sometimes, often, never, which, usually, generally,
# Nearest to an: mouton, seduction, picchi, philippi, haughty, ym, incompatible, glee,
# Nearest to by: using, through, be, in, been, sulawesi, was, pancakes,
# Nearest to UNK: kerry, stabilised, cardinal, zion, vlaamse, chinatown, c, faro,
# Nearest to to: would, will, must, might, can, may, modernised, should,
# Nearest to one: two, six, four, seven, eight, nine, three, five,
# Nearest to three: four, six, two, five, seven, eight, nine, zero,
# Nearest to which: that, this, what, also, however, but, actually, desiderius,
# Nearest to while: although, though, however, when, before, but, including, if,
# Nearest to often: sometimes, usually, commonly, frequently, generally, widely, still, now,
# Nearest to for: in, while, cluster, buoyant, including, without, against, if,
# Nearest to in: within, during, on, for, until, nunn, since, alibi,
# Nearest to there: they, it, now, still, we, he, she, usually,
# Nearest to or: and, while, any, than, fruits, thayer, uplink, shells,
# Nearest to united: gallbladder, seventh, koichi, past, itt, petrified, sap, convenes,
# Nearest to so: thus, lacked, barrington, freda, sometimes, then, anthropic, too,
# Average loss at step 72000: 3.374921
# Average loss at step 74000: 3.343207
# Average loss at step 76000: 3.310520
# Average loss at step 78000: 3.354937
# Average loss at step 80000: 3.381823
# Nearest to also: now, still, sometimes, often, which, never, usually, commonly,
# Nearest to an: picchi, glee, haughty, mouton, microwaves, seduction, fasting, cooperated,
# Nearest to by: through, when, using, pancakes, from, fins, eisler, kettering,
# Nearest to UNK: paddock, mircea, fukuoka, susannah, sir, clearest, yonkers, alexius,
# Nearest to to: must, would, please, minus, irritation, ella, festive, can,
# Nearest to one: seven, six, two, four, eight, three, five, nine,
# Nearest to three: four, six, five, seven, two, eight, nine, zero,
# Nearest to which: that, this, also, itself, usually, what, fick, who,
# Nearest to while: although, when, though, however, before, but, after, during,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, widely, still,
# Nearest to for: including, overturning, constitutionalism, although, eva, buoyant, against, immortal,
# Nearest to in: during, on, within, until, at, despite, alibi, since,
# Nearest to there: they, it, he, still, now, we, she, usually,
# Nearest to or: and, than, decomposed, while, habitation, slobodan, but, kanji,
# Nearest to united: gallbladder, koichi, seventh, itt, convenes, city, overridden, protestors,
# Nearest to so: barrington, lacked, thus, freda, tanistry, too, very, conjunctivitis,
# Average loss at step 82000: 3.406664
# Average loss at step 84000: 3.411604
# Average loss at step 86000: 3.390625
# Average loss at step 88000: 3.349072
# Average loss at step 90000: 3.364119
# Nearest to also: now, still, often, sometimes, which, generally, never, actually,
# Nearest to an: mouton, haughty, another, attrition, akbar, philippi, ym, guaranteed,
# Nearest to by: through, using, under, pancakes, with, while, when, being,
# Nearest to UNK: kerry, vlaamse, lascaris, tidy, incapacity, connor, guy, ludlow,
# Nearest to to: must, towards, would, maidstone, lobbies, will, could, dharmas,
# Nearest to one: seven, two, eight, four, six, three, five, nine,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to which: that, this, what, usually, also, actually, itself, who,
# Nearest to while: although, when, though, before, during, however, after, but,
# Nearest to often: sometimes, usually, commonly, frequently, generally, widely, typically, now,
# Nearest to for: including, of, without, overturning, against, saviour, after, flapping,
# Nearest to in: within, during, under, between, throughout, at, alibi, from,
# Nearest to there: they, it, still, he, now, she, generally, usually,
# Nearest to or: and, hinayana, though, decomposed, mise, while, categorizing, parisians,
# Nearest to united: confederate, gallbladder, seventh, itt, koichi, devoiced, convenes, protestors,
# Nearest to so: thus, lacked, conjunctivitis, barrington, too, if, ramjet, tanistry,
# Average loss at step 92000: 3.397350
# Average loss at step 94000: 3.252203
# Average loss at step 96000: 3.361471
# Average loss at step 98000: 3.243366
# Average loss at step 100000: 3.358567
# Nearest to also: now, still, sometimes, often, generally, never, which, usually,
# Nearest to an: another, haughty, seduction, paws, philippi, retorted, glee, mouton,
# Nearest to by: through, when, using, pancakes, against, with, under, kettering,
# Nearest to UNK: vp, hilltop, betts, joking, franck, broome, stars, peters,
# Nearest to to: will, would, could, nyc, must, and, biographers, toppings,
# Nearest to one: two, seven, eight, four, three, five, six, nine,
# Nearest to three: four, five, two, eight, seven, six, nine, zero,
# Nearest to which: that, this, what, it, who, actually, also, however,
# Nearest to while: although, when, though, however, before, if, but, after,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, widely, still,
# Nearest to for: against, without, when, including, after, although, despite, if,
# Nearest to in: within, during, throughout, alibi, on, near, against, at,
# Nearest to there: they, it, now, he, still, she, we, often,
# Nearest to or: and, than, decomposed, mcmahon, suborder, heredity, while, thayer,
# Nearest to united: confederate, itt, gallbladder, seventh, koichi, convenes, overridden, symbology,
# Nearest to so: thus, too, barrington, when, lacked, ramjet, insists, then,
# CPU times: user 12min 17s, sys: 35.1 s, total: 12min 52s
# Wall time: 6min 43s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
