# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'originated', 'a', 'term', 'as', 'of', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                        stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
            inputs=embed, labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time

num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.951431
# Nearest to nine: alternatives, reference, diger, nephropathy, supra, kindness, althing, pittsburgh,
# Nearest to for: computes, alliaceae, libretto, psychotherapy, stagnation, hardly, lazio, retained,
# Nearest to also: slowdown, liquefaction, apparent, str, livingston, chievo, canola, clouded,
# Nearest to years: infocom, sport, cordilleras, wolfgang, dou, andrei, spacecraft, ammanati,
# Nearest to one: uscis, searchers, whittaker, kammu, haircut, narrowest, nupedia, invest,
# Nearest to world: delete, br, failings, grouped, payloads, kinnock, managerial, palazzo,
# Nearest to b: transitional, fiefdom, vassal, invalid, lens, piecemeal, domesticated, palahniuk,
# Nearest to between: adder, nutrient, scavullo, ao, deviations, suppressive, pity, feats,
# Nearest to united: plein, peasants, heartbeat, resurrect, cnt, breakdance, successive, dyeing,
# Nearest to which: federer, abiding, piston, airing, backlash, skydiving, freenet, rana,
# Nearest to however: atonality, downloadable, dtv, penis, blair, rickenbacker, jai, entendre,
# Nearest to have: stillness, willem, cairns, bassoon, ascribed, pawns, strands, toward,
# Nearest to american: bayer, cleopatra, perhaps, stephan, resolved, heston, henze, ashland,
# Nearest to on: trevelyan, cinder, amtrak, lanphier, outings, meets, interrelated, copps,
# Nearest to was: free, camra, lament, irc, lam, amnon, acids, menstrual,
# Nearest to four: flexibility, marian, scorpion, programmability, midst, aggression, changeable, recalcitrant,
# Average loss at step 2000: 4.349354
# Average loss at step 4000: 3.866541
# Average loss at step 6000: 3.786297
# Average loss at step 8000: 3.686000
# Average loss at step 10000: 3.618754
# Nearest to nine: eight, seven, six, five, zero, three, four, two,
# Nearest to for: from, of, in, with, corneille, dominate, computes, corporations,
# Nearest to also: often, it, which, not, feminists, ordnance, who, nocturnal,
# Nearest to years: infocom, brighton, sport, sources, spacecraft, andrei, bison, bullets,
# Nearest to one: six, three, five, four, two, seven, eight, genji,
# Nearest to world: delete, br, pune, flourishes, vor, swedes, kinnock, differentials,
# Nearest to b: and, lens, nigh, vegeta, theologiae, propanol, distributing, widow,
# Nearest to between: with, brainchild, in, nutrient, notre, tran, ferocity, legions,
# Nearest to united: cnt, heartbeat, successive, plein, dyeing, milgrom, peasants, pindar,
# Nearest to which: that, this, it, often, also, who, ceremonies, elegantly,
# Nearest to however: downloadable, atonality, blair, jai, dtv, hike, thunderbirds, aftermath,
# Nearest to have: had, has, be, drachma, are, thant, witnessed, were,
# Nearest to american: bayer, stephan, cossack, virginia, furthest, weddings, spaniard, constituci,
# Nearest to on: in, at, cinder, slowly, from, through, guards, against,
# Nearest to was: is, has, had, by, were, be, been, sustaining,
# Nearest to four: six, three, five, eight, seven, two, nine, zero,
# Average loss at step 12000: 3.608348
# Average loss at step 14000: 3.571655
# Average loss at step 16000: 3.409581
# Average loss at step 18000: 3.455974
# Average loss at step 20000: 3.537146
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to for: with, of, corporations, destabilization, from, against, in, disneyland,
# Nearest to also: often, which, sometimes, ordnance, eventually, now, who, not,
# Nearest to years: infocom, brighton, frf, times, bullets, biotite, approximately, sport,
# Nearest to one: four, two, three, eight, six, seven, five, nine,
# Nearest to world: vor, delete, pune, kinnock, carlin, aleksandar, autocrat, br,
# Nearest to b: d, theologiae, lens, madison, propanol, radiometer, nigh, emo,
# Nearest to between: with, nutrient, notre, from, regarding, metabolite, among, legions,
# Nearest to united: heartbeat, milgrom, successive, cnt, pindar, peasants, dyeing, plein,
# Nearest to which: that, this, who, also, never, it, there, often,
# Nearest to however: but, that, atonality, downloadable, blair, like, thunderbirds, intermediate,
# Nearest to have: had, has, were, be, are, cherished, drachma, thant,
# Nearest to american: british, australian, french, intentional, english, logistical, misplaced, bayer,
# Nearest to on: in, at, cinder, through, upon, from, guards, frontman,
# Nearest to was: is, were, has, had, be, been, are, became,
# Nearest to four: six, seven, eight, three, five, two, nine, zero,
# Average loss at step 22000: 3.502443
# Average loss at step 24000: 3.492805
# Average loss at step 26000: 3.480276
# Average loss at step 28000: 3.481598
# Average loss at step 30000: 3.502115
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to for: corporations, against, of, with, from, legendary, haider, deceased,
# Nearest to also: often, sometimes, ordnance, which, now, it, actually, who,
# Nearest to years: brighton, times, bullets, approximately, year, days, infocom, frf,
# Nearest to one: two, seven, four, six, eight, three, five, nine,
# Nearest to world: vor, frontier, carlin, pune, swedes, verizon, trilled, hammers,
# Nearest to b: d, madison, theologiae, pergamon, lens, petrus, analog, emo,
# Nearest to between: with, among, nutrient, from, in, agricola, legions, regarding,
# Nearest to united: heartbeat, milgrom, successive, peasants, cnt, dyeing, pindar, backyard,
# Nearest to which: this, that, who, it, also, what, negro, but,
# Nearest to however: but, happily, atonality, pickett, like, graceland, while, blair,
# Nearest to have: had, has, were, are, be, juggernaut, needham, haka,
# Nearest to american: british, english, australian, french, german, canadian, cleaved, scottish,
# Nearest to on: in, upon, through, from, cinder, at, against, frontman,
# Nearest to was: is, were, had, has, became, been, when, does,
# Nearest to four: five, three, six, seven, eight, two, nine, zero,
# Average loss at step 32000: 3.502564
# Average loss at step 34000: 3.491912
# Average loss at step 36000: 3.451384
# Average loss at step 38000: 3.302566
# Average loss at step 40000: 3.424385
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to for: against, of, in, when, destabilization, giordano, digit, by,
# Nearest to also: often, which, sometimes, usually, now, still, there, typically,
# Nearest to years: times, days, brighton, months, approximately, bullets, year, mtu,
# Nearest to one: seven, six, four, eight, two, five, nine, three,
# Nearest to world: aleksandar, hammers, bullets, delete, carlin, frontier, potentially, vor,
# Nearest to b: d, UNK, mug, pleasures, sds, c, madison, shortages,
# Nearest to between: with, among, nutrient, regarding, vor, agricola, depleted, metabolite,
# Nearest to united: milgrom, heartbeat, successive, dyeing, peasants, us, pindar, cnt,
# Nearest to which: that, this, who, also, often, it, usually, what,
# Nearest to however: but, though, although, graceland, that, while, nullification, pickett,
# Nearest to have: had, has, were, are, be, include, witnessed, haka,
# Nearest to american: british, australian, german, english, french, canadian, cleaved, embassy,
# Nearest to on: upon, against, dog, cinder, at, through, hadadezer, strawberries,
# Nearest to was: is, had, were, has, been, became, when, be,
# Nearest to four: six, five, three, seven, eight, two, nine, one,
# Average loss at step 42000: 3.433543
# Average loss at step 44000: 3.455981
# Average loss at step 46000: 3.450794
# Average loss at step 48000: 3.349090
# Average loss at step 50000: 3.383214
# Nearest to nine: eight, seven, six, four, five, three, zero, one,
# Nearest to for: including, against, while, on, albigensians, of, and, computes,
# Nearest to also: now, often, which, sometimes, typically, marcius, eventually, still,
# Nearest to years: days, times, months, brighton, year, centuries, bullets, mtu,
# Nearest to one: two, six, four, eight, seven, five, three, nine,
# Nearest to world: delete, vor, bullets, hammers, carlin, frontier, peculiarities, potentially,
# Nearest to b: d, f, flannery, sds, secombe, v, pleasures, c,
# Nearest to between: among, with, regarding, nutrient, vor, marker, from, insurgencies,
# Nearest to united: milgrom, heartbeat, successive, whitcomb, peasants, dyeing, clemens, titanic,
# Nearest to which: that, this, often, also, usually, who, now, typically,
# Nearest to however: but, although, though, when, while, that, where, and,
# Nearest to have: had, has, were, are, be, include, oxidize, needham,
# Nearest to american: australian, british, azhar, french, international, english, embassy, scholastic,
# Nearest to on: upon, in, against, cinder, through, at, frontman, purports,
# Nearest to was: is, were, has, had, became, been, be, hamito,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Average loss at step 52000: 3.434072
# Average loss at step 54000: 3.429648
# Average loss at step 56000: 3.439487
# Average loss at step 58000: 3.394145
# Average loss at step 60000: 3.394896
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to for: including, against, of, to, if, destabilization, when, computes,
# Nearest to also: now, often, sometimes, still, typically, commonly, actually, usually,
# Nearest to years: days, times, months, centuries, brighton, year, decades, hours,
# Nearest to one: four, seven, two, six, eight, five, three, nine,
# Nearest to world: gulf, delete, hammers, bullets, peculiarities, frontier, sio, vor,
# Nearest to b: d, c, m, secombe, f, guyanese, meter, mug,
# Nearest to between: among, with, nutrient, regarding, notre, in, insurgencies, metabolite,
# Nearest to united: milgrom, heartbeat, dyeing, backyard, whitcomb, us, peasants, clemens,
# Nearest to which: that, this, typically, it, also, who, usually, often,
# Nearest to however: but, though, although, that, when, before, sixths, while,
# Nearest to have: has, had, were, are, include, having, be, attribute,
# Nearest to american: australian, english, british, german, azhar, international, floated, scottish,
# Nearest to on: upon, through, trevelyan, against, echols, cinder, in, interrelated,
# Nearest to was: is, became, had, were, has, although, been, be,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Average loss at step 62000: 3.241094
# Average loss at step 64000: 3.257308
# Average loss at step 66000: 3.398091
# Average loss at step 68000: 3.393626
# Average loss at step 70000: 3.360301
# Nearest to nine: eight, seven, six, five, four, three, zero, one,
# Nearest to for: in, wilmot, while, including, against, when, to, waikato,
# Nearest to also: now, often, still, sometimes, usually, which, actually, never,
# Nearest to years: days, months, centuries, decades, times, year, hours, brighton,
# Nearest to one: six, two, seven, eight, four, five, nine, three,
# Nearest to world: delete, gulf, vietnam, bullets, langford, pistols, uninterrupted, hammers,
# Nearest to b: d, f, r, m, guyanese, c, sds, secombe,
# Nearest to between: among, with, nutrient, within, regarding, in, from, insurgencies,
# Nearest to united: milgrom, heartbeat, dyeing, whitcomb, clemens, us, peasants, backyard,
# Nearest to which: that, this, usually, often, also, still, typically, what,
# Nearest to however: but, although, though, that, when, while, where, sixths,
# Nearest to have: had, has, were, are, include, be, having, noord,
# Nearest to american: australian, british, english, azhar, german, embassy, intentional, scholastic,
# Nearest to on: upon, through, in, cinder, against, remarkably, at, about,
# Nearest to was: is, has, were, had, been, became, be, timer,
# Nearest to four: five, six, three, seven, eight, nine, zero, two,
# Average loss at step 72000: 3.372526
# Average loss at step 74000: 3.350021
# Average loss at step 76000: 3.309747
# Average loss at step 78000: 3.356194
# Average loss at step 80000: 3.376597
# Nearest to nine: eight, seven, six, five, four, three, zero, births,
# Nearest to for: including, against, waikato, sha, rout, pursuits, while, curious,
# Nearest to also: often, sometimes, now, still, usually, which, commonly, actually,
# Nearest to years: days, months, centuries, decades, times, hours, year, weeks,
# Nearest to one: seven, six, eight, three, two, four, five, hammerheads,
# Nearest to world: delete, gulf, vietnam, carlin, uninterrupted, westward, quarreled, rhodesia,
# Nearest to b: d, c, f, m, bleach, sds, r, meter,
# Nearest to between: among, nutrient, within, regarding, with, insurgencies, over, in,
# Nearest to united: dyeing, milgrom, heartbeat, peasants, us, whitcomb, refectory, same,
# Nearest to which: this, that, usually, attendance, also, often, who, mandola,
# Nearest to however: although, but, that, though, while, where, when, unwavering,
# Nearest to have: had, has, having, are, be, include, were, refer,
# Nearest to american: australian, british, german, english, canadian, embassy, azhar, brazilian,
# Nearest to on: upon, in, through, at, against, guards, catoctin, around,
# Nearest to was: is, became, were, has, been, had, stipulation, be,
# Nearest to four: five, six, three, eight, seven, nine, two, zero,
# Average loss at step 82000: 3.405757
# Average loss at step 84000: 3.408362
# Average loss at step 86000: 3.389214
# Average loss at step 88000: 3.348365
# Average loss at step 90000: 3.366689
# Nearest to nine: seven, eight, five, six, four, zero, births, three,
# Nearest to for: including, against, while, of, during, groot, through, waikato,
# Nearest to also: often, still, actually, now, sometimes, which, never, usually,
# Nearest to years: days, months, centuries, decades, hours, year, percent, weeks,
# Nearest to one: seven, eight, four, two, six, three, five, th,
# Nearest to world: delete, vietnam, duets, sio, gulf, eleftherios, waco, swedes,
# Nearest to b: d, f, m, bleach, c, whammy, r, cooper,
# Nearest to between: among, with, within, nutrient, regarding, in, insurgencies, metabolite,
# Nearest to united: milgrom, dyeing, heartbeat, dude, constitution, refectory, titanic, whitcomb,
# Nearest to which: that, this, usually, also, what, often, who, these,
# Nearest to however: but, although, that, though, while, when, especially, where,
# Nearest to have: had, has, were, having, include, be, are, noord,
# Nearest to american: australian, british, english, canadian, german, italian, european, brazilian,
# Nearest to on: upon, through, at, under, guards, against, purports, echols,
# Nearest to was: is, had, became, were, has, be, been, although,
# Nearest to four: five, seven, three, eight, six, two, nine, zero,
# Average loss at step 92000: 3.391927
# Average loss at step 94000: 3.250825
# Average loss at step 96000: 3.357108
# Average loss at step 98000: 3.244352
# Average loss at step 100000: 3.355219
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to for: when, against, if, including, computes, before, allowing, although,
# Nearest to also: actually, now, still, sometimes, often, never, usually, always,
# Nearest to years: days, months, centuries, year, hours, decades, times, percent,
# Nearest to one: four, two, seven, eight, five, three, six, nine,
# Nearest to world: delete, vietnam, gulf, filing, uninterrupted, sio, swedes, eleftherios,
# Nearest to b: d, c, steiger, symbolically, pergamon, amati, obtains, mad,
# Nearest to between: among, with, nutrient, within, regarding, metabolite, oracles, woodland,
# Nearest to united: milgrom, dyeing, heartbeat, constitution, dude, refectory, whitcomb, ged,
# Nearest to which: that, this, what, usually, often, typically, these, also,
# Nearest to however: but, although, though, that, while, where, and, especially,
# Nearest to have: had, has, include, are, were, having, be, refer,
# Nearest to american: british, australian, canadian, italian, french, english, german, brazilian,
# Nearest to on: upon, at, through, in, against, cinder, around, strawberries,
# Nearest to was: is, became, were, has, had, been, being, be,
# Nearest to four: six, seven, five, eight, three, nine, two, zero,
# CPU times: user 12min 45s, sys: 38.3 s, total: 13min 24s
# Wall time: 7min 31s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
