# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.

# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'originated', 'term', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 

valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Random seed
    tf.set_random_seed(1)
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                        stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases,
            inputs=embed, labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time

num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.861717
# Nearest to more: alleviation, accord, allegiances, trace, goodman, rabies, bader, peculiarly,
# Nearest to eight: ruling, www, landscapes, wh, promulgate, spanking, registration, friars,
# Nearest to after: dish, leveraged, principal, richer, digital, theophilus, triode, counterparts,
# Nearest to will: canonized, isolation, gearbox, wap, thrice, hypermedia, hays, desserts,
# Nearest to used: faithful, alkynes, uw, multiples, smf, darpa, revisionists, propaganda,
# Nearest to see: saviour, antioxidants, burn, rocking, forearms, sparked, congratulations, ttt,
# Nearest to his: recreationally, sliced, lebrun, beanstalk, extant, incited, magnified, stafford,
# Nearest to most: alters, decoy, snooker, mg, climbs, cortisol, olivia, frail,
# Nearest to were: distributors, allotropes, slater, stories, sandy, flickr, monitored, stapleton,
# Nearest to had: livius, wilburys, macromolecules, threat, elsinore, logs, chk, sayer,
# Nearest to between: hwa, governorship, attesting, butchers, slashes, reductions, trips, fy,
# Nearest to states: mutagenic, shire, philo, irb, eurydice, caste, ata, gottes,
# Nearest to all: nesting, warranties, electrons, accountant, coe, qq, sheppard, hearted,
# Nearest to new: alemanni, macht, atlantean, skiego, wissenschaften, danielle, ordinances, fraud,
# Nearest to they: tanned, maronite, congregationalism, aquilonia, flavian, gorillaz, gettysburg, rambla,
# Nearest to can: horus, maimed, four, deposed, safavids, kambojas, gordie, dummy,
# Average loss at step 2000: 4.356299
# Average loss at step 4000: 3.864637
# Average loss at step 6000: 3.790171
# Average loss at step 8000: 3.687376
# Average loss at step 10000: 3.610903
# Nearest to more: uucp, slashes, look, rather, accord, rabies, allegiances, seamstress,
# Nearest to eight: six, nine, seven, five, four, three, zero, two,
# Nearest to after: payroll, before, first, in, richer, appoint, ceding, principal,
# Nearest to will: can, thule, canonized, bourgeoisie, thrice, hypermedia, gearbox, decrease,
# Nearest to used: faithful, known, consternation, multiples, roshan, humans, uw, astronautics,
# Nearest to see: but, saviour, antioxidants, fathoms, odd, ulrike, johannesburg, burn,
# Nearest to his: her, their, s, the, its, sapkowski, extant, this,
# Nearest to most: alters, refinery, decoy, mg, alice, spaceflights, climbs, defections,
# Nearest to were: are, was, slater, propounded, have, by, and, foiled,
# Nearest to had: has, have, was, livius, vegetative, could, poly, attributing,
# Nearest to between: meditations, homeopaths, absence, ciphertexts, happier, in, solo, coda,
# Nearest to states: philo, gottes, chopping, carpathian, acrylic, suit, mutagenic, meteorite,
# Nearest to all: many, accountant, some, perturbed, orthogonal, any, rush, people,
# Nearest to new: macht, danielle, argand, ludi, wissenschaften, slaps, atlantean, taxation,
# Nearest to they: he, not, there, rambla, flavian, sumerian, it, i,
# Nearest to can: may, will, should, would, must, could, judiciary, unipolar,
# Average loss at step 12000: 3.604512
# Average loss at step 14000: 3.564453
# Average loss at step 16000: 3.409333
# Average loss at step 18000: 3.457302
# Average loss at step 20000: 3.541558
# Nearest to more: less, accord, most, very, rather, slimmer, look, pickering,
# Nearest to eight: seven, nine, four, six, five, three, zero, two,
# Nearest to after: before, when, at, from, during, principal, payroll, digital,
# Nearest to will: can, may, would, must, could, should, might, to,
# Nearest to used: known, found, faithful, humans, multiples, granted, grander, kampuchea,
# Nearest to see: but, rousing, fortune, antioxidants, saviour, damping, maxim, ulrike,
# Nearest to his: their, her, its, the, sapkowski, extant, minutemen, cholesterol,
# Nearest to most: more, alters, refinery, some, decoy, reinhardt, defections, maharaja,
# Nearest to were: are, was, had, have, be, bells, by, is,
# Nearest to had: has, have, was, were, vegetative, buddy, could, opry,
# Nearest to between: including, in, meditations, with, swiss, lucky, sized, impoverishment,
# Nearest to states: gottes, carpathian, philo, chopping, eads, appendix, acrylic, shire,
# Nearest to all: many, some, any, those, bruins, tracey, methodological, introspective,
# Nearest to new: macht, danielle, sanitary, fraud, alemanni, wissenschaften, divisions, ludi,
# Nearest to they: there, he, we, it, not, who, i, she,
# Nearest to can: may, will, could, would, should, must, might, cherries,
# Average loss at step 22000: 3.500138
# Average loss at step 24000: 3.491574
# Average loss at step 26000: 3.481871
# Average loss at step 28000: 3.476117
# Average loss at step 30000: 3.502197
# Nearest to more: less, very, rather, most, accord, better, slimmer, slashes,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to after: before, during, when, at, from, payroll, in, was,
# Nearest to will: would, can, may, could, must, should, might, shall,
# Nearest to used: known, found, multiples, faithful, humans, referred, granted, called,
# Nearest to see: but, ceasing, antioxidants, damping, cosmonaut, dae, interchangeability, are,
# Nearest to his: her, their, its, the, s, anacharsis, my, unresolved,
# Nearest to most: more, many, some, alters, refinery, among, reinhardt, beginnings,
# Nearest to were: are, was, have, had, is, propounded, been, scuderia,
# Nearest to had: have, has, was, were, vegetative, could, having, buddy,
# Nearest to between: with, against, in, meditations, lucky, eigenstates, sized, swiss,
# Nearest to states: philo, gottes, countries, eads, carpathian, shire, tensions, acrylic,
# Nearest to all: some, many, any, these, methodological, simcoe, immediately, either,
# Nearest to new: durant, danielle, second, alemanni, unix, dmitri, informants, lyc,
# Nearest to they: there, he, we, it, you, who, these, not,
# Nearest to can: may, could, will, would, should, must, might, cherries,
# Average loss at step 32000: 3.497251
# Average loss at step 34000: 3.493274
# Average loss at step 36000: 3.451964
# Average loss at step 38000: 3.297027
# Average loss at step 40000: 3.431669
# Nearest to more: less, most, very, rather, better, accord, smaller, relatively,
# Nearest to eight: nine, seven, six, five, four, three, zero, two,
# Nearest to after: before, during, when, intermixed, gyro, payroll, blenheim, had,
# Nearest to will: would, can, may, could, should, must, might, shall,
# Nearest to used: found, known, referred, identified, considered, seen, held, written,
# Nearest to see: but, ulrike, cosmonaut, can, interchangeability, ceasing, include, indy,
# Nearest to his: their, her, its, the, s, my, minutemen, our,
# Nearest to most: more, some, among, many, refinery, alters, conjuring, mccall,
# Nearest to were: are, have, was, had, scuderia, propounded, be, been,
# Nearest to had: has, have, was, buddy, were, blenheim, opry, vegetative,
# Nearest to between: with, over, around, against, sized, hamito, mounds, eigenstates,
# Nearest to states: countries, philo, tensions, kingdom, gottes, eads, forces, ist,
# Nearest to all: both, any, many, these, methodological, several, immediately, ish,
# Nearest to new: informants, durant, correlation, danielle, ludi, dismissing, woodpecker, indeterminate,
# Nearest to they: we, he, there, you, it, i, these, who,
# Nearest to can: could, may, will, would, should, must, might, cherries,
# Average loss at step 42000: 3.432171
# Average loss at step 44000: 3.453554
# Average loss at step 46000: 3.449933
# Average loss at step 48000: 3.352175
# Average loss at step 50000: 3.380302
# Nearest to more: less, most, very, rather, increasingly, better, smaller, accord,
# Nearest to eight: six, nine, four, seven, five, three, zero, two,
# Nearest to after: before, during, when, while, colon, was, throughout, upon,
# Nearest to will: would, can, could, must, may, should, might, cannot,
# Nearest to used: known, found, referred, written, seen, designed, considered, identified,
# Nearest to see: cosmonaut, frac, include, can, colonna, tend, permit, ttir,
# Nearest to his: her, their, its, my, your, minutemen, our, anacharsis,
# Nearest to most: more, many, among, some, refinery, less, alters, balkan,
# Nearest to were: are, was, have, had, be, scuderia, those, alde,
# Nearest to had: has, have, was, having, were, blenheim, opry, vegetative,
# Nearest to between: with, in, around, eigenstates, against, sized, harmonics, including,
# Nearest to states: kingdom, countries, gottes, philo, carpathian, tensions, nations, upsets,
# Nearest to all: both, methodological, any, breakfast, ish, bruins, various, out,
# Nearest to new: woodpecker, garnered, urbanized, durant, correlation, indeterminate, plazas, mathematical,
# Nearest to they: we, he, there, you, she, it, these, unpowered,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Average loss at step 52000: 3.435882
# Average loss at step 54000: 3.425432
# Average loss at step 56000: 3.437848
# Average loss at step 58000: 3.399921
# Average loss at step 60000: 3.390798
# Nearest to more: less, rather, better, very, most, smaller, accord, increasingly,
# Nearest to eight: nine, six, seven, four, three, five, zero, two,
# Nearest to after: before, during, when, while, without, although, despite, gyro,
# Nearest to will: would, could, can, must, may, should, might, cannot,
# Nearest to used: known, referred, found, seen, called, designed, written, identified,
# Nearest to see: but, cosmonaut, include, ttir, cezanne, can, list, frac,
# Nearest to his: her, their, its, my, the, our, your, minutemen,
# Nearest to most: more, many, some, balkan, use, alters, several, conjuring,
# Nearest to were: are, have, was, had, including, although, those, been,
# Nearest to had: has, have, was, were, having, blenheim, could, been,
# Nearest to between: with, among, harmonics, mergesort, eigenstates, around, over, hamito,
# Nearest to states: kingdom, countries, nations, eads, forces, chopping, carpathian, lundy,
# Nearest to all: both, many, some, various, those, methodological, heretic, any,
# Nearest to new: garnered, durant, woodpecker, informants, nascent, lyc, vaccine, discussing,
# Nearest to they: we, there, he, you, she, these, it, who,
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Average loss at step 62000: 3.240037
# Average loss at step 64000: 3.259105
# Average loss at step 66000: 3.403480
# Average loss at step 68000: 3.393871
# Average loss at step 70000: 3.358385
# Nearest to more: less, most, rather, very, better, cowardice, accord, smaller,
# Nearest to eight: nine, six, seven, four, five, zero, three, two,
# Nearest to after: before, during, when, while, despite, without, richer, through,
# Nearest to will: would, could, can, may, must, should, might, cannot,
# Nearest to used: known, found, designed, referred, seen, written, called, regarded,
# Nearest to see: list, include, but, cosmonaut, can, tend, skyview, colonna,
# Nearest to his: her, their, its, my, your, our, the, posteriori,
# Nearest to most: more, many, some, less, several, balkan, use, mccall,
# Nearest to were: are, have, was, had, be, been, scuderia, while,
# Nearest to had: has, have, was, were, having, blenheim, been, certify,
# Nearest to between: with, among, around, eigenstates, through, hamito, harmonics, sized,
# Nearest to states: kingdom, countries, nations, tensions, upsets, state, carpathian, sources,
# Nearest to all: both, some, many, every, methodological, heretic, various, any,
# Nearest to new: garnered, nascent, aldehydes, woodpecker, vaccine, discussing, correlation, mathematical,
# Nearest to they: we, he, there, you, it, she, who, these,
# Nearest to can: may, could, will, would, must, should, might, cannot,
# Average loss at step 72000: 3.369909
# Average loss at step 74000: 3.343672
# Average loss at step 76000: 3.320966
# Average loss at step 78000: 3.348595
# Average loss at step 80000: 3.381277
# Nearest to more: less, very, rather, most, better, smaller, increasingly, accord,
# Nearest to eight: nine, six, five, four, seven, three, zero, two,
# Nearest to after: before, during, when, while, despite, without, in, speller,
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to used: known, referred, found, written, available, depicted, considered, defined,
# Nearest to see: ttir, tend, but, include, ceiling, refers, according, zhaozhou,
# Nearest to his: her, their, its, my, your, the, our, minutemen,
# Nearest to most: many, more, some, mccall, among, frightened, alters, balkan,
# Nearest to were: are, had, was, have, include, been, irons, being,
# Nearest to had: have, has, were, was, having, never, been, blenheim,
# Nearest to between: among, with, eigenstates, around, through, in, over, microtonal,
# Nearest to states: kingdom, nations, countries, cultures, forces, lundy, quod, albans,
# Nearest to all: both, every, each, many, some, various, heretic, any,
# Nearest to new: sopra, aldehydes, informants, landmasses, durant, garnered, skynyrd, lepers,
# Nearest to they: we, he, there, you, she, it, who, unpowered,
# Nearest to can: could, may, will, must, would, should, might, cannot,
# Average loss at step 82000: 3.406818
# Average loss at step 84000: 3.408153
# Average loss at step 86000: 3.389083
# Average loss at step 88000: 3.352768
# Average loss at step 90000: 3.360846
# Nearest to more: less, very, rather, most, smaller, better, pickering, cowardice,
# Nearest to eight: seven, six, nine, five, four, three, zero, two,
# Nearest to after: before, during, while, when, despite, without, until, from,
# Nearest to will: would, could, must, can, might, should, may, cannot,
# Nearest to used: referred, known, found, considered, called, written, designed, depicted,
# Nearest to see: list, ttir, include, cezanne, external, references, birding, suppose,
# Nearest to his: her, their, its, your, my, our, s, minutemen,
# Nearest to most: more, many, some, mccall, balkan, among, use, less,
# Nearest to were: are, had, have, was, while, scuderia, these, those,
# Nearest to had: has, have, were, was, having, opry, joh, blenheim,
# Nearest to between: with, around, eigenstates, in, among, through, including, against,
# Nearest to states: kingdom, nations, countries, lundy, cultures, lok, appendix, carpathian,
# Nearest to all: both, many, every, some, several, various, these, each,
# Nearest to new: garnered, modern, sopra, ordinances, girlfriends, old, landmasses, particular,
# Nearest to they: we, he, there, you, she, it, soon, who,
# Nearest to can: could, must, may, will, would, should, might, cannot,
# Average loss at step 92000: 3.392536
# Average loss at step 94000: 3.255294
# Average loss at step 96000: 3.356800
# Average loss at step 98000: 3.233820
# Average loss at step 100000: 3.360118
# Nearest to more: less, most, very, better, cowardice, rather, smaller, increasingly,
# Nearest to eight: seven, nine, six, four, five, three, zero, two,
# Nearest to after: before, during, when, despite, while, without, until, qa,
# Nearest to will: would, could, must, can, may, might, should, cannot,
# Nearest to used: referred, found, known, considered, depicted, written, designed, defined,
# Nearest to see: references, list, external, links, refers, suppose, ceiling, can,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to most: more, less, balkan, among, refinery, many, especially, mccall,
# Nearest to were: are, was, have, had, scuderia, including, these, transgressions,
# Nearest to had: has, have, was, having, were, opry, blenheim, vegetative,
# Nearest to between: with, around, eigenstates, through, among, over, meditations, blank,
# Nearest to states: kingdom, nations, countries, us, presheaf, cultures, lok, samoa,
# Nearest to all: many, these, every, both, several, various, some, unbeaten,
# Nearest to new: creole, garnered, aldehydes, sopra, fraud, different, grandchildren, modern,
# Nearest to they: we, he, there, you, she, it, soon, not,
# Nearest to can: could, may, must, will, would, should, might, cannot,
# CPU times: user 12min 16s, sys: 34.3 s, total: 12min 51s
# Wall time: 6min 31s

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %% time
#
# def plot(embeddings, labels):
#     assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
#     pylab.figure(figsize=(15,15))  # in inches
#     for i, label in enumerate(labels):
#         x, y = embeddings[i,:]
#         pylab.scatter(x, y)
#         pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
#                    ha='right', va='bottom')
#     pylab.show()
#
# words = [reverse_dictionary[i] for i in range(1, num_points+1)]
# plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Implement CBOW

data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']

# %%
for bag_window in [1, 2]:
	data_index = 0
	batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
	print('\nwith bag_window = %d:' % (bag_window))
	print('		batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])
	print('		labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# with bag_window = 1:
# 		batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
# 		labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
# 		batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
# 		labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128 #dim of embedding vector
bag_window = 2
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

	# Set random seed 
	tf.set_random_seed(1)

	# Input data
	train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
	train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
	valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

	# Variables
	embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size],
		-1.0, 1.0))
	softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size,
		embedding_size], stddev=1.0 / math.sqrt(embedding_size)))
	softmax_biases 	= tf.Variable(tf.zeros([vocabulary_size]))

	# Model
	# Look up embeddings for inputs
	embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
	# Compute the softmax loss using a sample of the neg labels each time
	loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights,
		softmax_biases, tf.reduce_sum(embeds, 1), train_labels, num_sampled,
		vocabulary_size))

	# Optimizer
	optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

	# Compute cosine similarity
	norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
	normalized_embeddings = embeddings / norm
	valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
	similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
# %%time

num_steps = 100001

with tf.Session(graph=graph) as session:
	tf.initialize_all_variables().run()
	print('Initialized')
	average_loss = 0
	for step in range(num_steps):
		batch_data, batch_labels = generate_batch(batch_size, bag_window)
		feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
		_, l = session.run([optimizer, loss], feed_dict=feed_dict)
		average_loss += l
		if step % 2000 == 0:
			if step > 0:
				average_loss = average_loss / 2000
			# avg loss is est over last 2000 batches
			print('Average loss at step %d: %f' % (step, average_loss))
			average_loss = 0
		if step % 10000 == 0:
			sim = similarity.eval()
			for i in range(valid_size):
				valid_word = reverse_dictionary[valid_examples[i]]
				top_k = 8
				nearest = (-sim[i, :]).argsort()[1:top_k+1]
				log = 'Nearest to %s:' % valid_word
				for k in range(top_k):
					close_word = reverse_dictionary[nearest[k]]
					log = '%s %s,' % (log, close_word)
				print(log)
	final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.193523
# Nearest to a: courts, bryozoans, realising, acting, lengthwise, disapproval, nebraska, bartholomew,
# Nearest to more: alleviation, accord, allegiances, trace, goodman, rabies, bader, peculiarly,
# Nearest to these: distorts, cadbury, swerve, gallifrey, meat, espouse, bengal, revolvers,
# Nearest to with: hamlet, defun, lives, bridgetown, revivals, potawatomi, mixers, factories,
# Nearest to time: dna, suicides, dixie, athenaeum, asterism, modulo, druidism, thickly,
# Nearest to were: distributors, allotropes, slater, stories, sandy, flickr, monitored, stapleton,
# Nearest to three: galvanized, haden, controllable, unequivocally, unsuspecting, californium, teil, demigod,
# Nearest to while: outages, steinberg, sailors, hittites, orangutan, accords, keats, frazee,
# Nearest to had: livius, wilburys, macromolecules, threat, elsinore, logs, chk, sayer,
# Nearest to often: grundlagen, superoxide, heiress, guard, coronations, piccard, utica, landsat,
# Nearest to when: lott, betrayal, detectives, opencourseware, freeport, capitalised, staking, maria,
# Nearest to up: eased, rden, lye, toriyama, taliaferro, eliyahu, blackburn, peak,
# Nearest to been: jazeera, discriminatory, impersonal, alde, wane, typeface, staring, metre,
# Nearest to of: beheading, shankar, inquire, supercontinent, koreans, springsteen, lner, couper,
# Nearest to however: pascal, slit, utica, sedimentary, colonize, titian, salom, cryptanalyst,
# Nearest to is: serving, deserve, disquieting, schliemann, hippocampus, practice, anticonvulsants, gram,
# Average loss at step 2000: 8.230178
# Average loss at step 4000: 4.536917
# Average loss at step 6000: 4.961576
# Average loss at step 8000: 4.291713
# Average loss at step 10000: 4.248308
# Nearest to a: the, any, causality, this, another, no, dartmoor, corona,
# Nearest to more: rather, less, greater, buddhist, those, most, projective, vaccine,
# Nearest to these: other, meat, yosemite, they, some, furies, diverges, satyagraha,
# Nearest to with: between, from, constabulary, px, alcindor, using, while, angels,
# Nearest to time: period, lamentations, test, benoit, least, devise, beginning, zero,
# Nearest to were: are, was, foiled, zn, bloc, adelaide, slater, fibrosis,
# Nearest to three: five, four, seven, six, two, eight, abilene, humbucker,
# Nearest to while: aids, oregon, hiv, apple, applet, louisiana, astoria, only,
# Nearest to had: has, have, sheeana, myles, opry, chapman, pane, collateral,
# Nearest to often: commonly, also, generally, equally, centrum, sometimes, pvc, kinase,
# Nearest to when: governs, if, where, reliant, sch, mng, vulgate, stimulating,
# Nearest to up: nightingale, blackburn, varuna, saragossa, steamboat, stanislav, undermined, encompassed,
# Nearest to been: become, intercollegiate, obscured, holbein, bowles, rodent, aristide, rijeka,
# Nearest to of: rep, chests, gravis, magazines, rescheduled, symbiosis, crusades, width,
# Nearest to however: pascal, chrismation, since, that, preserved, though, slit, skiing,
# Nearest to is: was, has, became, are, be, valiant, roamed, seems,
# Average loss at step 12000: 4.595590
# Average loss at step 14000: 3.952657
# Average loss at step 16000: 3.945947
# Average loss at step 18000: 3.716570
# Average loss at step 20000: 3.543845
# Nearest to a: the, another, an, causality, corea, ona, boers, syncopation,
# Nearest to more: less, rather, better, ezra, how, both, relatively, average,
# Nearest to these: various, other, different, certain, yosemite, some, several, many,
# Nearest to with: interrogated, milligrams, constabulary, revocation, when, between, ios, featuring,
# Nearest to time: since, later, aids, abba, ben, phenomenon, oregon, mari,
# Nearest to were: are, was, is, have, include, became, had, lough,
# Nearest to three: six, seven, five, pounds, ebbets, colspan, tod, ar,
# Nearest to while: when, shave, and, condiments, falk, supersede, persecute, among,
# Nearest to had: has, have, having, was, were, occultists, qq, includes,
# Nearest to often: sometimes, usually, generally, commonly, still, frequently, brooding, also,
# Nearest to when: if, where, while, after, between, bradman, pb, voter,
# Nearest to up: nightingale, off, them, out, aino, encompassed, prosecution, undermined,
# Nearest to been: become, jazeera, undergone, being, whitewater, correction, metrication, lastly,
# Nearest to of: kiln, stereotypes, rescheduled, livingstone, mingling, unbound, playhouse, surround,
# Nearest to however: although, though, kelvins, submarine, that, thinkpad, iblis, mnr,
# Nearest to is: was, are, became, were, has, afterword, plaintiffs, cog,
# Average loss at step 22000: 3.573121
# Average loss at step 24000: 3.450349
# Average loss at step 26000: 3.570891
# Average loss at step 28000: 3.517433
# Average loss at step 30000: 3.371432
# Nearest to a: another, every, the, any, causality, afflicted, an, monopolist,
# Nearest to more: less, aka, rather, increasingly, costumed, lower, most, better,
# Nearest to these: many, other, different, various, some, several, furies, those,
# Nearest to with: between, revocation, uncompromising, including, against, ios, and, scofield,
# Nearest to time: least, point, year, period, beginning, praetorians, cynical, quart,
# Nearest to were: are, was, include, had, is, highness, became, rijeka,
# Nearest to three: four, six, five, seven, eight, two, colspan, ccd,
# Nearest to while: and, although, before, though, chipping, against, however, because,
# Nearest to had: has, have, having, was, gave, took, were, saw,
# Nearest to often: sometimes, commonly, usually, frequently, still, also, widely, commercials,
# Nearest to when: if, because, before, where, governs, neoclassicism, at, reliant,
# Nearest to up: off, out, thracians, them, him, back, repulsive, encompassed,
# Nearest to been: become, come, rijeka, undergone, holbein, shaved, existed, junta,
# Nearest to of: in, among, for, cushitic, hetfield, rlc, urbanized, during,
# Nearest to however: although, though, but, because, that, until, while, where,
# Nearest to is: was, are, has, contains, remains, became, makes, includes,
# Average loss at step 32000: 3.188911
# Average loss at step 34000: 3.368973
# Average loss at step 36000: 3.335009
# Average loss at step 38000: 3.235841
# Average loss at step 40000: 3.282359
# Nearest to a: another, any, the, every, each, syncopation, this, an,
# Nearest to more: less, rather, very, better, too, smaller, most, greater,
# Nearest to these: various, those, certain, several, different, many, furies, there,
# Nearest to with: between, adoptive, jelly, using, without, syllogism, nrms, while,
# Nearest to time: least, stage, point, beginning, times, approval, distance, praetorians,
# Nearest to were: are, was, is, include, had, became, have, be,
# Nearest to three: four, two, six, eight, seven, five, ufc, losers,
# Nearest to while: and, though, although, but, including, towards, despite, kullervo,
# Nearest to had: has, have, having, was, gave, were, includes, sacrificing,
# Nearest to often: commonly, usually, sometimes, frequently, generally, still, widely, also,
# Nearest to when: oregon, abba, sound, aids, mash, ballads, applet, bust,
# Nearest to up: off, out, thracians, workflow, sacrificed, indifference, efforts, kyi,
# Nearest to been: become, be, undergone, metrication, begun, resulted, was, himself,
# Nearest to of: kiln, hetfield, throughout, during, cushitic, in, for, livingstone,
# Nearest to however: ballads, bust, bankruptcy, sound, abba, aids, marlowe, applet,
# Nearest to is: was, are, were, remains, includes, has, contains, makes,
# Average loss at step 42000: 3.296972
# Average loss at step 44000: 3.304126
# Average loss at step 46000: 3.251167
# Average loss at step 48000: 3.182730
# Average loss at step 50000: 3.242966
# Nearest to a: any, the, another, afflicted, causality, syncopation, beckton, gabonese,
# Nearest to more: less, rather, very, most, too, better, greater, extremely,
# Nearest to these: various, different, certain, multiple, several, many, which, valentino,
# Nearest to with: between, using, nrms, dl, renewing, revocation, without, sickness,
# Nearest to time: least, distance, times, point, year, end, praetorians, beginning,
# Nearest to were: are, was, is, being, include, exist, be, became,
# Nearest to three: six, four, five, cpsu, deeply, applet, batting, convolution,
# Nearest to while: although, when, however, where, and, among, including, because,
# Nearest to had: has, have, having, could, was, means, saw, would,
# Nearest to often: usually, sometimes, commonly, frequently, generally, still, also, what,
# Nearest to when: where, before, if, while, until, since, after, because,
# Nearest to up: applet, signal, cpsu, marlowe, crew, results, bankruptcy, mem,
# Nearest to been: become, undergone, resulted, occurred, come, rijeka, begun, appeared,
# Nearest to of: include, including, represents, kiln, during, trier, in, boasts,
# Nearest to however: although, while, that, though, since, but, spaceship, which,
# Nearest to is: was, are, became, makes, contains, remains, has, provides,
# Average loss at step 52000: 3.183632
# Average loss at step 54000: 3.180386
# Average loss at step 56000: 3.012187
# Average loss at step 58000: 3.105117
# Average loss at step 60000: 3.190656
# Nearest to a: another, the, any, every, no, causality, feasts, syncopation,
# Nearest to more: less, rather, very, better, most, quite, greater, smaller,
# Nearest to these: various, several, different, certain, many, those, some, other,
# Nearest to with: between, including, revocation, nrms, had, among, meteorology, jelly,
# Nearest to time: period, least, night, distance, beginning, approval, point, year,
# Nearest to were: are, was, is, being, foiled, retire, remained, remain,
# Nearest to three: four, five, six, seven, two, eight, zero, kaposi,
# Nearest to while: although, and, among, than, but, though, or, including,
# Nearest to had: has, have, having, was, gave, saw, took, wrote,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, also, still,
# Nearest to when: where, if, before, because, until, since, also, during,
# Nearest to up: off, out, down, back, guatemalans, together, away, wanted,
# Nearest to been: jonah, hanukkah, echo, bankruptcy, oregon, state, results, rabbinical,
# Nearest to of: kiln, include, hetfield, since, following, before, deserters, rep,
# Nearest to however: though, although, since, but, if, because, that, while,
# Nearest to is: was, are, became, becomes, has, remains, makes, were,
# Average loss at step 62000: 3.094849
# Average loss at step 64000: 2.991718
# Average loss at step 66000: 3.032288
# Average loss at step 68000: 3.095060
# Average loss at step 70000: 3.079938
# Nearest to a: the, any, another, every, no, syncopation, soaked, causality,
# Nearest to more: less, rather, very, better, most, greater, smaller, larger,
# Nearest to these: various, those, some, several, different, their, certain, valentino,
# Nearest to with: between, featuring, syllogism, jelly, vater, among, hey, conrad,
# Nearest to time: performance, unconnected, afterlife, compromise, maximum, diamond, temperatures, cruz,
# Nearest to were: are, was, had, is, remain, ascendancy, including, remained,
# Nearest to three: five, six, seven, two, four, eight, kaposi, toby,
# Nearest to while: but, although, and, when, neoclassicism, though, however, among,
# Nearest to had: has, have, having, were, eventually, was, conformist, sacrificing,
# Nearest to often: sometimes, usually, frequently, commonly, generally, still, typically, now,
# Nearest to when: if, although, because, before, then, while, though, during,
# Nearest to up: off, down, back, out, spouses, together, thalberg, wins,
# Nearest to been: become, existed, grown, be, survived, appeared, resulted, undergone,
# Nearest to of: including, for, kiln, in, following, hetfield, while, throughout,
# Nearest to however: although, though, but, while, spaceship, despite, since, ecumenism,
# Nearest to is: was, becomes, makes, are, remains, includes, became, provides,
# Average loss at step 72000: 2.991996
# Average loss at step 74000: 2.942422
# Average loss at step 76000: 3.074482
# Average loss at step 78000: 3.061149
# Average loss at step 80000: 2.895064
# Nearest to a: another, any, every, the, syncopation, no, flannery, malpractice,
# Nearest to more: less, rather, very, most, smaller, better, highly, greater,
# Nearest to these: several, certain, those, various, different, they, some, there,
# Nearest to with: between, involving, revocation, among, nrms, colic, milligrams, sickness,
# Nearest to time: beginning, times, daime, battlefield, point, battle, night, period,
# Nearest to were: are, was, is, had, remained, been, include, bunyan,
# Nearest to three: four, six, five, seven, two, consigned, eight, anni,
# Nearest to while: although, though, however, where, when, and, than, aud,
# Nearest to had: has, have, having, wali, were, could, was, robbery,
# Nearest to often: generally, frequently, commonly, sometimes, usually, widely, typically, now,
# Nearest to when: if, where, though, before, although, after, since, finally,
# Nearest to up: off, down, out, back, together, workflow, away, mems,
# Nearest to been: become, come, existed, appeared, resulted, survived, begun, remained,
# Nearest to of: including, kiln, include, during, following, while, mailing, in,
# Nearest to however: although, but, though, since, while, circulate, despite, when,
# Nearest to is: was, becomes, makes, contains, are, has, includes, provides,
# Average loss at step 82000: 2.981231
# Average loss at step 84000: 2.942489
# Average loss at step 86000: 2.971347
# Average loss at step 88000: 3.006242
# Average loss at step 90000: 2.913130
# Nearest to a: another, the, any, every, this, syncopation, malpractice, atat,
# Nearest to more: less, rather, very, too, better, smaller, extremely, most,
# Nearest to these: different, various, certain, several, those, few, specific, their,
# Nearest to with: between, among, involving, vater, featuring, revocation, extensible, milligrams,
# Nearest to time: least, beginning, daime, night, end, aimed, approval, distance,
# Nearest to were: are, was, is, represent, had, newly, include, fibrosis,
# Nearest to three: seven, four, eight, copps, dewar, grunwald, pan, ch,
# Nearest to while: although, however, and, when, where, though, or, unlike,
# Nearest to had: has, have, having, was, wali, wrote, gave, includes,
# Nearest to often: generally, usually, sometimes, commonly, typically, actually, widely, always,
# Nearest to when: if, where, although, because, during, indeed, frequently, while,
# Nearest to up: off, back, down, together, kyi, workflow, place, prostitute,
# Nearest to been: become, remained, existed, fallen, occurred, grown, resulted, recently,
# Nearest to of: in, following, involves, hetfield, kiln, during, include, for,
# Nearest to however: although, though, but, while, when, since, where, and,
# Nearest to is: was, are, becomes, remains, provides, has, became, includes,
# Average loss at step 92000: 2.945153
# Average loss at step 94000: 2.942547
# Average loss at step 96000: 2.784357
# Average loss at step 98000: 2.545226
# Average loss at step 100000: 2.768748
# Nearest to a: another, the, any, every, something, afflicted, syncopation, finkel,
# Nearest to more: less, extremely, smaller, rather, costumed, too, most, longer,
# Nearest to these: other, such, repaired, gchq, number, x, grunwald, various,
# Nearest to with: involving, between, revocation, among, vater, defun, syllogism, featuring,
# Nearest to time: point, daime, moment, night, start, least, age, period,
# Nearest to were: are, was, various, include, several, remain, is, fibrosis,
# Nearest to three: seven, four, five, two, six, nov, number, eight,
# Nearest to while: averages, mash, broadsheet, louisiana, debtor, gchq, hanukkah, applet,
# Nearest to had: has, have, was, conformist, qq, having, contains, includes,
# Nearest to often: generally, usually, sometimes, commonly, typically, also, widely, frequently,
# Nearest to when: if, where, although, because, though, which, until, since,
# Nearest to up: out, away, cpsu, decision, applet, across, eta, dialect,
# Nearest to been: become, remained, fallen, existed, occurred, grown, undergone, resulted,
# Nearest to of: kiln, including, in, for, involves, hetfield, representing, livingstone,
# Nearest to however: although, but, though, that, because, when, including, and,
# Nearest to is: was, provides, contains, makes, includes, became, remains, are,
# CPU times: user 15min 55s, sys: 36.2 s, total: 16min 31s
# Wall time: 8min 2s

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %%time

def plot(embeddings, labels):
	assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
	pylab.figure(figsize=(15,15)) # in inches, what?
	for i, label in enumerate(labels):
		x, y = embeddings[i,:]
		pylab.scatter(x, y)
		pylab.annotate(label, xy=(x,y), xytext=(5,2), textcoords='offset points',
			ha='right', va='bottom')
	pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# CPU times: user 5.21 s, sys: 92 ms, total: 5.3 s
# Wall time: 5.33 s
